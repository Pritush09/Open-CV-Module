# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritush09/Open-CV-Module/blob/master/Understanding_of_an_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2

# %%
im = cv2.imread('/content/goku.jpg')

# %%
im.shape
# Out:
# (1244, 800, 3)

# %%
height , width = im.shape[:2]
height , width
# Out:
# (1244, 800)

# %%
from google.colab.patches import  cv2_imshow # this is for showing the image
cv2_imshow(im)

# done other way in local by 
# cv.waitKey(0) to tell python that untill there is pressing of key the img will show 
# cv.destroyALLWINDOWS()
# Out:
# <PIL.Image.Image image mode=RGB size=800x1244 at 0x7F093108EA60>

# %%
im[100,100] # matlab 100th row aur 100th column
# in open cv RGB is written as  BGR values not like we learn as RGB
# Out:
# array([39, 27, 15], dtype=uint8)
