# %%
import cv2
import numpy as np

# %% [markdown]
# # HSV
# * It is a hue saturation value
# * R,G,B or opposite it connected with the luminance(color ki intensity) ke satah corelated he
# but just by looking at the intensity we can not understand the information of that image
# * but using HSV or HSL it gives is all the info about the image its intensity its value and its saturation
#
# # The below is hexagon model of color
# ![image.png](attachment:image.png)

# %%
img = cv2.imread("C:/Users/mynam/Downloads/balls_img.jpg")
img = cv2.resize(img,(600,400))
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
while 1:
    hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
    #113, 252, 71 r,g,b
    u_v = np.array([71,252,113])
    #53, 120, 32 r, g, b
    l_v = cp.array([32,120,53])
    # creating a mask
    mask = cv2.inRange(hsv,l_v,u_v)
